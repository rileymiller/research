# %% [markdown]
# # HITS Count Data Analysis
#
# Analysis on general dataset characteristics

# %%
import pandas as pd
from time import time

t0 = time()

hits = pd.read_json('datasets/20200126-20200312-hits.json', lines=True)


print('INFO: done reading in dataset to pandas dataframe in %0.3fs.' % (time() - t0))
# Out:
# INFO: done reading in dataset to pandas dataframe in 551.146s.

# %%
hits.head()
# Out:
#                                     _id                      hit_set_id  \
# 0  {'$oid': '5e2e07e440666269314f6d76'}  3GRRK9BQWROCIFPJTJ74ZZLB6ZIPDI
# 1  {'$oid': '5e2e07e440666269314f6d77'}  345DFELIOAW9BTA7ZVPRUL1PDQGX0G
# 2  {'$oid': '5e2e07e440666269314f6d78'}  3JCELWMC3O86LDKV3Z1AWANP7583V6
# 3  {'$oid': '5e2e07e440666269314f6d79'}  320GLP60AN5TS9K5PU8IGRVPKUZ14P
# 4  {'$oid': '5e2e07e440666269314f6d7a'}  389X50RO3UCP2CYKCYM14K9RJJI439
#
#      requester_id requester_name  \
# 0  A13PNDK4YW47PL         amturk
# 1  A3UENPLNM9AQBK        BIU NLP
# 2   AAE8HYZ2P1HCS            A2Z
# 3  A38RXMI7DFPL8G    411Richmond
# 4  A38RXMI7DFPL8G    411Richmond
#
#                                                title  \
# 0      Input specific values displayed in the image.
# 1  Write question-answer pairs about verbal nouns...
# 2                      Data Entry from images (P641)
# 3  Extract purchased items from a shopping receip...
# 4               Verify a single value from a receipt
#
#                                          description  \
# 0  You will be presented an image of a gym cardio...
# 1  Given a sentence and a noun from that sentence...
# 2                       Transcribing data from image
# 3  Extract all the items from the receipt. You wi...
# 4  Verify the value of single data point (such as...
#
#   assignment_duration_in_seconds             creation_time  \
# 0                           3600 2020-01-26 21:42:51+00:00
# 1                           3600 2020-01-26 21:42:50+00:00
# 2                            600 2020-01-26 21:42:49+00:00
# 3                           5400 2020-01-26 21:42:46+00:00
# 4                           1800 2020-01-26 21:42:46+00:00
#
#   assignable_hits_count    latest_expiration_time  caller_meets_requirements  \
# 0                     1 2020-01-27 02:42:51+00:00                      False
# 1                    34 2020-02-25 21:42:50+00:00                      False
# 2                     1 2020-02-02 21:42:49+00:00                      False
# 3                     1 2020-02-02 21:42:46+00:00                       True
# 4                     6 2020-02-02 21:42:46+00:00                       True
#
#    caller_meets_preview_requirements         last_updated_time  \
# 0                               True 2020-01-26 21:42:51+00:00
# 1                              False 2020-01-26 21:42:50+00:00
# 2                              False 2020-01-26 21:42:49+00:00
# 3                               True 2020-01-26 21:42:46+00:00
# 4                               True 2020-01-26 21:42:46+00:00
#
#                                      monetary_reward  \
# 0  {'currency_code': 'USD', 'amount_in_dollars': ...
# 1  {'currency_code': 'USD', 'amount_in_dollars': ...
# 2  {'currency_code': 'USD', 'amount_in_dollars': ...
# 3  {'currency_code': 'USD', 'amount_in_dollars': ...
# 4  {'currency_code': 'USD', 'amount_in_dollars': ...
#
#                              accept_project_task_url  \
# 0  /projects/3GRRK9BQWROCIFPJTJ74ZZLB6ZIPDI/tasks...
# 1  /projects/345DFELIOAW9BTA7ZVPRUL1PDQGX0G/tasks...
# 2  /projects/3JCELWMC3O86LDKV3Z1AWANP7583V6/tasks...
# 3  /projects/320GLP60AN5TS9K5PU8IGRVPKUZ14P/tasks...
# 4  /projects/389X50RO3UCP2CYKCYM14K9RJJI439/tasks...
#
#                                        requester_url  \
# 0  /requesters/A13PNDK4YW47PL/projects?ref=w_pl_prvw
# 1  /requesters/A3UENPLNM9AQBK/projects?ref=w_pl_prvw
# 2   /requesters/AAE8HYZ2P1HCS/projects?ref=w_pl_prvw
# 3  /requesters/A38RXMI7DFPL8G/projects?ref=w_pl_prvw
# 4  /requesters/A38RXMI7DFPL8G/projects?ref=w_pl_prvw
#
#                                    project_tasks_url  \
# 0  /projects/3GRRK9BQWROCIFPJTJ74ZZLB6ZIPDI/tasks...
# 1  /projects/345DFELIOAW9BTA7ZVPRUL1PDQGX0G/tasks...
# 2  /projects/3JCELWMC3O86LDKV3Z1AWANP7583V6/tasks...
# 3  /projects/320GLP60AN5TS9K5PU8IGRVPKUZ14P/tasks...
# 4  /projects/389X50RO3UCP2CYKCYM14K9RJJI439/tasks...
#
#                                 project_requirements  \
# 0  [{'qualification_type_id': '3Q48MW141AXN97AOAE...
# 1  [{'qualification_type_id': '000000000000000000...
# 2  [{'qualification_type_id': '000000000000000000...
# 3                                                 []
# 4                                                 []
#
#                                        requesterInfo
# 0  {'activityLevel': 'High', 'taskApprovalRate': ...
# 1  {'activityLevel': 'High', 'taskApprovalRate': ...
# 2  {'activityLevel': 'High', 'taskApprovalRate': ...
# 3  {'activityLevel': 'High', 'taskApprovalRate': ...
# 4  {'activityLevel': 'High', 'taskApprovalRate': ...

# %%
t0 = time()

print('INFO: sorting hits by creation time')
hits = hits.sort_values('hit_set_id')

print('INFO: finished sorting hits by creation time in %.3fs' % (time() - t0))
hits.head(100)
# Out:
# INFO: sorting hits by creation time
# INFO: finished sorting hits by creation time in 6.739s
#                                          _id                      hit_set_id  \
# 675168  {'$oid': '5e5d118957e1a5286a3729f4'}  301G7MYOAJ2YTXU1RQ4DF6YHYOC532
# 828063  {'$oid': '5e613a1e7e1d55505b6211eb'}  301G7MYOAJ4JDGPW3YS47DXL2T535X
# 828059  {'$oid': '5e613a197e1d55505b6211e4'}  301G7MYOAJ4JDGPW3YS47DXL2T535X
# 829545  {'$oid': '5e6143f728d6d9251cd81307'}  301G7MYOAJ4JDGPW3YS47DXL2T535X
# 829539  {'$oid': '5e6143ec28d6d9251cd812fd'}  301G7MYOAJ4JDGPW3YS47DXL2T535X
# ...                                      ...                             ...
# 142416  {'$oid': '5e33abf52c7f5f22a3e1bdec'}  301G7MYOBKEIY4KG1MZQ3JV9TQS53L
# 145170  {'$oid': '5e33d5db0a98f020692e64cf'}  301G7MYOBKEIY4KG1MZQ3JV9TQT53M
# 147771  {'$oid': '5e34102d0907a43336d56990'}  301G7MYOBKEIY4KG1MZQ3JV9TQU53N
# 153533  {'$oid': '5e3454d42a4383605e9b5950'}  301G7MYOBKEIY4KG1MZQ3JV9TQV53O
# 162724  {'$oid': '5e349030f24ab635ffd57518'}  301G7MYOBKEIY4KG1MZQ3JV9TQX53Q
#
#           requester_id     requester_name  \
# 675168  A1S51OLVMWXAC8  Michele Rigolizzo
# 828063   AL9XTUAY2PZGZ                J N
# 828059   AL9XTUAY2PZGZ                J N
# 829545   AL9XTUAY2PZGZ                J N
# 829539   AL9XTUAY2PZGZ                J N
# ...                ...                ...
# 142416  A2WBREJD1LX8IV       Rece Capture
# 145170  A2WBREJD1LX8IV       Rece Capture
# 147771  A2WBREJD1LX8IV       Rece Capture
# 153533  A2WBREJD1LX8IV       Rece Capture
# 162724  A2WBREJD1LX8IV       Rece Capture
#
#                                                     title  \
# 675168  Two-Part Study for a total of $2.50. Part 1 pa...
# 828063                      Multiple studies(~ 7 minutes)
# 828059                      Multiple studies(~ 7 minutes)
# 829545                      Multiple studies(~ 7 minutes)
# 829539                      Multiple studies(~ 7 minutes)
# ...                                                   ...
# 142416                    Audit The Receipt Transcription
# 145170                    Audit The Receipt Transcription
# 147771                    Audit The Receipt Transcription
# 153533                    Audit The Receipt Transcription
# 162724                    Audit The Receipt Transcription
#
#                                               description  \
# 675168  This is a two part study. Part 1 pays $1 and P...
# 828063  A survey on your opinions with a chance to win...
# 828059  A survey on your opinions with a chance to win...
# 829545  A survey on your opinions with a chance to win...
# 829539  A survey on your opinions with a chance to win...
# ...                                                   ...
# 142416  Audit whether the information contained in the...
# 145170  Audit whether the information contained in the...
# 147771  Audit whether the information contained in the...
# 153533  Audit whether the information contained in the...
# 162724  Audit whether the information contained in the...
#
#        assignment_duration_in_seconds             creation_time  \
# 675168         {'$numberInt': '1800'} 2020-03-02 14:00:31+00:00
# 828063                           2400 2020-03-05 17:42:44+00:00
# 828059                           2400 2020-03-05 17:42:41+00:00
# 829545                           2400 2020-03-05 18:24:37+00:00
# 829539                           2400 2020-03-05 18:24:34+00:00
# ...                               ...                       ...
# 142416                           1200 2020-01-31 04:23:40+00:00
# 145170                           1200 2020-01-31 07:22:42+00:00
# 147771                           1200 2020-01-31 11:31:40+00:00
# 153533                           1200 2020-01-31 16:24:40+00:00
# 162724                           1200 2020-01-31 20:37:41+00:00
#
#        assignable_hits_count    latest_expiration_time  \
# 675168   {'$numberInt': '7'} 2020-04-01 14:00:31+00:00
# 828063                    44 2020-03-08 17:42:44+00:00
# 828059                    23 2020-03-08 17:42:41+00:00
# 829545                    26 2020-03-08 18:24:37+00:00
# 829539                    20 2020-03-08 18:24:34+00:00
# ...                      ...                       ...
# 142416                     1 2020-02-05 04:23:40+00:00
# 145170                     1 2020-02-05 07:22:42+00:00
# 147771                     1 2020-02-05 11:31:40+00:00
# 153533                     1 2020-02-05 16:24:40+00:00
# 162724                     1 2020-02-05 20:37:41+00:00
#
#         caller_meets_requirements  caller_meets_preview_requirements  \
# 675168                      False                              False
# 828063                      False                              False
# 828059                      False                              False
# 829545                      False                              False
# 829539                      False                              False
# ...                           ...                                ...
# 142416                       True                               True
# 145170                       True                               True
# 147771                       True                               True
# 153533                       True                               True
# 162724                       True                               True
#
#                last_updated_time  \
# 675168 2020-03-02 14:00:31+00:00
# 828063 2020-03-05 17:42:44+00:00
# 828059 2020-03-05 17:42:41+00:00
# 829545 2020-03-05 18:24:37+00:00
# 829539 2020-03-05 18:24:34+00:00
# ...                          ...
# 142416 2020-01-31 04:23:40+00:00
# 145170 2020-01-31 07:22:42+00:00
# 147771 2020-01-31 11:31:40+00:00
# 153533 2020-01-31 16:24:40+00:00
# 162724 2020-01-31 20:37:41+00:00
#
#                                           monetary_reward  \
# 675168  {'currency_code': 'USD', 'amount_in_dollars': ...
# 828063  {'currency_code': 'USD', 'amount_in_dollars': ...
# 828059  {'currency_code': 'USD', 'amount_in_dollars': ...
# 829545  {'currency_code': 'USD', 'amount_in_dollars': ...
# 829539  {'currency_code': 'USD', 'amount_in_dollars': ...
# ...                                                   ...
# 142416  {'currency_code': 'USD', 'amount_in_dollars': ...
# 145170  {'currency_code': 'USD', 'amount_in_dollars': ...
# 147771  {'currency_code': 'USD', 'amount_in_dollars': ...
# 153533  {'currency_code': 'USD', 'amount_in_dollars': ...
# 162724  {'currency_code': 'USD', 'amount_in_dollars': ...
#
#                                   accept_project_task_url  \
# 675168  /projects/301G7MYOAJ2YTXU1RQ4DF6YHYOC532/tasks...
# 828063  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 828059  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 829545  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 829539  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# ...                                                   ...
# 142416  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQS53L/tasks...
# 145170  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQT53M/tasks...
# 147771  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQU53N/tasks...
# 153533  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQV53O/tasks...
# 162724  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQX53Q/tasks...
#
#                                             requester_url  \
# 675168  /requesters/A1S51OLVMWXAC8/projects?ref=w_pl_prvw
# 828063   /requesters/AL9XTUAY2PZGZ/projects?ref=w_pl_prvw
# 828059   /requesters/AL9XTUAY2PZGZ/projects?ref=w_pl_prvw
# 829545   /requesters/AL9XTUAY2PZGZ/projects?ref=w_pl_prvw
# 829539   /requesters/AL9XTUAY2PZGZ/projects?ref=w_pl_prvw
# ...                                                   ...
# 142416  /requesters/A2WBREJD1LX8IV/projects?ref=w_pl_prvw
# 145170  /requesters/A2WBREJD1LX8IV/projects?ref=w_pl_prvw
# 147771  /requesters/A2WBREJD1LX8IV/projects?ref=w_pl_prvw
# 153533  /requesters/A2WBREJD1LX8IV/projects?ref=w_pl_prvw
# 162724  /requesters/A2WBREJD1LX8IV/projects?ref=w_pl_prvw
#
#                                         project_tasks_url  \
# 675168  /projects/301G7MYOAJ2YTXU1RQ4DF6YHYOC532/tasks...
# 828063  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 828059  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 829545  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 829539  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# ...                                                   ...
# 142416  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQS53L/tasks...
# 145170  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQT53M/tasks...
# 147771  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQU53N/tasks...
# 153533  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQV53O/tasks...
# 162724  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQX53Q/tasks...
#
#                                      project_requirements  \
# 675168  [{'qualification_type_id': '37LS5N5SV1PR0ZVHC6...
# 828063  [{'qualification_type_id': '000000000000000000...
# 828059  [{'qualification_type_id': '000000000000000000...
# 829545  [{'qualification_type_id': '000000000000000000...
# 829539  [{'qualification_type_id': '000000000000000000...
# ...                                                   ...
# 142416  [{'qualification_type_id': '3D05Y5UXI14XS7D0LO...
# 145170  [{'qualification_type_id': '3MCN1A5LKRIK40Y3FF...
# 147771  [{'qualification_type_id': '36GCPOW9EJ8CKFIOK5...
# 153533  [{'qualification_type_id': '32S8022MNRO9ZDU22V...
# 162724  [{'qualification_type_id': '3Z6U0SAT6ZCT75PN2H...
#
#                                             requesterInfo
# 675168  {'activityLevel': 'Limited', 'taskApprovalRate...
# 828063  {'activityLevel': 'Moderate', 'taskApprovalRat...
# 828059  {'activityLevel': 'Moderate', 'taskApprovalRat...
# 829545  {'activityLevel': 'Moderate', 'taskApprovalRat...
# 829539  {'activityLevel': 'Moderate', 'taskApprovalRat...
# ...                                                   ...
# 142416  {'activityLevel': 'High', 'taskApprovalRate': ...
# 145170  {'activityLevel': 'High', 'taskApprovalRate': ...
# 147771  {'activityLevel': 'High', 'taskApprovalRate': ...
# 153533  {'activityLevel': 'High', 'taskApprovalRate': ...
# 162724  {'activityLevel': 'High', 'taskApprovalRate': ...
#
# [100 rows x 19 columns]

# %%
print('INFO: shape of HITS df before drop dup: {}'.format(hits.shape))
hits = hits.drop_duplicates(subset=['hit_set_id', 'creation_time'], keep='first')
print('INFO: shape of HITS df after drop dup: {}'.format(hits.shape))

hits.head(100)
# Out:
# INFO: shape of HITS df before drop dup: (1108702, 19)
# INFO: shape of HITS df after drop dup: (1056308, 19)
#                                          _id                      hit_set_id  \
# 675168  {'$oid': '5e5d118957e1a5286a3729f4'}  301G7MYOAJ2YTXU1RQ4DF6YHYOC532
# 828063  {'$oid': '5e613a1e7e1d55505b6211eb'}  301G7MYOAJ4JDGPW3YS47DXL2T535X
# 828059  {'$oid': '5e613a197e1d55505b6211e4'}  301G7MYOAJ4JDGPW3YS47DXL2T535X
# 829545  {'$oid': '5e6143f728d6d9251cd81307'}  301G7MYOAJ4JDGPW3YS47DXL2T535X
# 829539  {'$oid': '5e6143ec28d6d9251cd812fd'}  301G7MYOAJ4JDGPW3YS47DXL2T535X
# ...                                      ...                             ...
# 162724  {'$oid': '5e349030f24ab635ffd57518'}  301G7MYOBKEIY4KG1MZQ3JV9TQX53Q
# 168548  {'$oid': '5e34be1b05e967702bbeb1c9'}  301G7MYOBKEIY4KG1MZQ3JV9TQZ53S
# 173190  {'$oid': '5e34e5f41a91805949a932e8'}  301G7MYOBKEIY4KG1MZQ3JV9TR153W
# 174517  {'$oid': '5e34f111d57e4e12fe61c060'}  301G7MYOBKEIY4KG1MZQ3JV9TRS53N
# 189622  {'$oid': '5e35c11087a8bb2255d297a8'}  301G7MYOBKEIY4KG1MZQ3JV9TRW53R
#
#           requester_id     requester_name  \
# 675168  A1S51OLVMWXAC8  Michele Rigolizzo
# 828063   AL9XTUAY2PZGZ                J N
# 828059   AL9XTUAY2PZGZ                J N
# 829545   AL9XTUAY2PZGZ                J N
# 829539   AL9XTUAY2PZGZ                J N
# ...                ...                ...
# 162724  A2WBREJD1LX8IV       Rece Capture
# 168548  A2WBREJD1LX8IV       Rece Capture
# 173190  A2WBREJD1LX8IV       Rece Capture
# 174517  A2WBREJD1LX8IV       Rece Capture
# 189622  A2WBREJD1LX8IV       Rece Capture
#
#                                                     title  \
# 675168  Two-Part Study for a total of $2.50. Part 1 pa...
# 828063                      Multiple studies(~ 7 minutes)
# 828059                      Multiple studies(~ 7 minutes)
# 829545                      Multiple studies(~ 7 minutes)
# 829539                      Multiple studies(~ 7 minutes)
# ...                                                   ...
# 162724                    Audit The Receipt Transcription
# 168548                    Audit The Receipt Transcription
# 173190                    Audit The Receipt Transcription
# 174517                    Audit The Receipt Transcription
# 189622                    Audit The Receipt Transcription
#
#                                               description  \
# 675168  This is a two part study. Part 1 pays $1 and P...
# 828063  A survey on your opinions with a chance to win...
# 828059  A survey on your opinions with a chance to win...
# 829545  A survey on your opinions with a chance to win...
# 829539  A survey on your opinions with a chance to win...
# ...                                                   ...
# 162724  Audit whether the information contained in the...
# 168548  Audit whether the information contained in the...
# 173190  Audit whether the information contained in the...
# 174517  Audit whether the information contained in the...
# 189622  Audit whether the information contained in the...
#
#        assignment_duration_in_seconds             creation_time  \
# 675168         {'$numberInt': '1800'} 2020-03-02 14:00:31+00:00
# 828063                           2400 2020-03-05 17:42:44+00:00
# 828059                           2400 2020-03-05 17:42:41+00:00
# 829545                           2400 2020-03-05 18:24:37+00:00
# 829539                           2400 2020-03-05 18:24:34+00:00
# ...                               ...                       ...
# 162724                           1200 2020-01-31 20:37:41+00:00
# 168548                           1200 2020-01-31 23:53:41+00:00
# 173190                           1200 2020-02-01 02:43:40+00:00
# 174517                           1200 2020-02-01 03:30:41+00:00
# 189622                           1200 2020-02-01 18:18:40+00:00
#
#        assignable_hits_count    latest_expiration_time  \
# 675168   {'$numberInt': '7'} 2020-04-01 14:00:31+00:00
# 828063                    44 2020-03-08 17:42:44+00:00
# 828059                    23 2020-03-08 17:42:41+00:00
# 829545                    26 2020-03-08 18:24:37+00:00
# 829539                    20 2020-03-08 18:24:34+00:00
# ...                      ...                       ...
# 162724                     1 2020-02-05 20:37:41+00:00
# 168548                     1 2020-02-05 23:53:41+00:00
# 173190                     1 2020-02-06 02:43:40+00:00
# 174517                     1 2020-02-06 03:30:41+00:00
# 189622                     1 2020-02-06 18:18:40+00:00
#
#         caller_meets_requirements  caller_meets_preview_requirements  \
# 675168                      False                              False
# 828063                      False                              False
# 828059                      False                              False
# 829545                      False                              False
# 829539                      False                              False
# ...                           ...                                ...
# 162724                       True                               True
# 168548                       True                               True
# 173190                       True                               True
# 174517                       True                               True
# 189622                       True                               True
#
#                last_updated_time  \
# 675168 2020-03-02 14:00:31+00:00
# 828063 2020-03-05 17:42:44+00:00
# 828059 2020-03-05 17:42:41+00:00
# 829545 2020-03-05 18:24:37+00:00
# 829539 2020-03-05 18:24:34+00:00
# ...                          ...
# 162724 2020-01-31 20:37:41+00:00
# 168548 2020-01-31 23:53:41+00:00
# 173190 2020-02-01 02:43:40+00:00
# 174517 2020-02-01 03:30:41+00:00
# 189622 2020-02-01 18:18:40+00:00
#
#                                           monetary_reward  \
# 675168  {'currency_code': 'USD', 'amount_in_dollars': ...
# 828063  {'currency_code': 'USD', 'amount_in_dollars': ...
# 828059  {'currency_code': 'USD', 'amount_in_dollars': ...
# 829545  {'currency_code': 'USD', 'amount_in_dollars': ...
# 829539  {'currency_code': 'USD', 'amount_in_dollars': ...
# ...                                                   ...
# 162724  {'currency_code': 'USD', 'amount_in_dollars': ...
# 168548  {'currency_code': 'USD', 'amount_in_dollars': ...
# 173190  {'currency_code': 'USD', 'amount_in_dollars': ...
# 174517  {'currency_code': 'USD', 'amount_in_dollars': ...
# 189622  {'currency_code': 'USD', 'amount_in_dollars': ...
#
#                                   accept_project_task_url  \
# 675168  /projects/301G7MYOAJ2YTXU1RQ4DF6YHYOC532/tasks...
# 828063  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 828059  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 829545  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 829539  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# ...                                                   ...
# 162724  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQX53Q/tasks...
# 168548  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQZ53S/tasks...
# 173190  /projects/301G7MYOBKEIY4KG1MZQ3JV9TR153W/tasks...
# 174517  /projects/301G7MYOBKEIY4KG1MZQ3JV9TRS53N/tasks...
# 189622  /projects/301G7MYOBKEIY4KG1MZQ3JV9TRW53R/tasks...
#
#                                             requester_url  \
# 675168  /requesters/A1S51OLVMWXAC8/projects?ref=w_pl_prvw
# 828063   /requesters/AL9XTUAY2PZGZ/projects?ref=w_pl_prvw
# 828059   /requesters/AL9XTUAY2PZGZ/projects?ref=w_pl_prvw
# 829545   /requesters/AL9XTUAY2PZGZ/projects?ref=w_pl_prvw
# 829539   /requesters/AL9XTUAY2PZGZ/projects?ref=w_pl_prvw
# ...                                                   ...
# 162724  /requesters/A2WBREJD1LX8IV/projects?ref=w_pl_prvw
# 168548  /requesters/A2WBREJD1LX8IV/projects?ref=w_pl_prvw
# 173190  /requesters/A2WBREJD1LX8IV/projects?ref=w_pl_prvw
# 174517  /requesters/A2WBREJD1LX8IV/projects?ref=w_pl_prvw
# 189622  /requesters/A2WBREJD1LX8IV/projects?ref=w_pl_prvw
#
#                                         project_tasks_url  \
# 675168  /projects/301G7MYOAJ2YTXU1RQ4DF6YHYOC532/tasks...
# 828063  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 828059  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 829545  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# 829539  /projects/301G7MYOAJ4JDGPW3YS47DXL2T535X/tasks...
# ...                                                   ...
# 162724  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQX53Q/tasks...
# 168548  /projects/301G7MYOBKEIY4KG1MZQ3JV9TQZ53S/tasks...
# 173190  /projects/301G7MYOBKEIY4KG1MZQ3JV9TR153W/tasks...
# 174517  /projects/301G7MYOBKEIY4KG1MZQ3JV9TRS53N/tasks...
# 189622  /projects/301G7MYOBKEIY4KG1MZQ3JV9TRW53R/tasks...
#
#                                      project_requirements  \
# 675168  [{'qualification_type_id': '37LS5N5SV1PR0ZVHC6...
# 828063  [{'qualification_type_id': '000000000000000000...
# 828059  [{'qualification_type_id': '000000000000000000...
# 829545  [{'qualification_type_id': '000000000000000000...
# 829539  [{'qualification_type_id': '000000000000000000...
# ...                                                   ...
# 162724  [{'qualification_type_id': '3Z6U0SAT6ZCT75PN2H...
# 168548  [{'qualification_type_id': '37IFZYW5I04P90FCPF...
# 173190  [{'qualification_type_id': '3HLGXCNWFCFNXF2U0U...
# 174517  [{'qualification_type_id': '3X437IA58BP09ZW26Q...
# 189622  [{'qualification_type_id': '3SCCRYYNFNPAOTUCS9...
#
#                                             requesterInfo
# 675168  {'activityLevel': 'Limited', 'taskApprovalRate...
# 828063  {'activityLevel': 'Moderate', 'taskApprovalRat...
# 828059  {'activityLevel': 'Moderate', 'taskApprovalRat...
# 829545  {'activityLevel': 'Moderate', 'taskApprovalRat...
# 829539  {'activityLevel': 'Moderate', 'taskApprovalRat...
# ...                                                   ...
# 162724  {'activityLevel': 'High', 'taskApprovalRate': ...
# 168548  {'activityLevel': 'High', 'taskApprovalRate': ...
# 173190  {'activityLevel': 'High', 'taskApprovalRate': ...
# 174517  {'activityLevel': 'High', 'taskApprovalRate': ...
# 189622  {'activityLevel': 'High', 'taskApprovalRate': ...
#
# [100 rows x 19 columns]

# %% [markdown]
# ### Unique requester in dataset

# %%
hits['requester_id'].nunique()
# Out:
# 4014

# %% [markdown]
# ### Unique Requester's by name

# %%
hits['requester_name'].value_counts().head(10)
# Out:
# Panel                391859
# Ibotta, Inc.          55485
# 411Richmond           54313
# Shopping Receipts     45732
# p9r                   42103
# Rece Capture          34105
# MLDataLabeler         32999
# TeamZ                 29838
# Crowdsurf Support     29052
# Job Spotter           23847
# Name: requester_name, dtype: int64

# %% [markdown]
# ### total number of hits

# %%
print(hits.shape[0])
requester_hits = hits['requester_name'].value_counts().tolist()
# print(requester_hits)
print('total num_hits: ', sum(requester_hits))


# print(requester_hits_name)
# requester_hits.plot.pie(y='requester_name', figsize=(5, 5))
# Out:
# 1056308
# total num_hits:  1056308

# %% [markdown]
# ### number of hits from top 10 requesters

# %%
top_ten_count = sum(requester_hits[:10])

print('top_ten_count:', top_ten_count)
# Out:
# top_ten_count: 739333

# %% [markdown]
# ### number of hits from the rest of the requesters

# %%
print('rest of requesters: ', sum(requester_hits[10:]))
# Out:
# rest of requesters:  316975

# %% [markdown]
# ### PiChart of top 10 requesters

# %%
import matplotlib.pyplot as plt

top_requesters = hits['requester_name'].value_counts().index.tolist()
top_requesters = top_requesters[:10]

top_requesters.append('Rest of Requesters')

top_req_hit_cnt = hits['requester_name'].value_counts().tolist()
top_req_hit_cnt = top_req_hit_cnt[:10]

rest_req_hit_cnt = sum(requester_hits[10:])
print(top_requesters)

top_req_hit_cnt.append(rest_req_hit_cnt)

print(top_req_hit_cnt)

print(len(top_req_hit_cnt))


requester_label = [ 'Requester #1', 'Requester #2','Requester #3','Requester #4','Requester #5','Requester #6','Requester #7',
                  'Requester #8','Requester #9', 'Requester #10', 'Rest of Requesters'
                  ]

colors = ['#d3e4a6', '#0b16aa', '#fc92c5', '#d2ae87', '#25ae9b', 
          '#d8dd75', '#76c3be', '#68cbdd', '#de4514', '#7c2789', 
          '#77334a'
         ]
print(len(requester_label))

print(requester_label)
# Pie chart, where the slices will be ordered and plotted counter-clockwise:


fig1, ax1 = plt.subplots(figsize=(14, 10))
ax1.pie(top_req_hit_cnt, labels=requester_label, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# ['Panel', 'Ibotta, Inc.', '411Richmond', 'Shopping Receipts', 'p9r', 'Rece Capture', 'MLDataLabeler', 'TeamZ', 'Crowdsurf Support', 'Job Spotter', 'Rest of Requesters']
# [391859, 55485, 54313, 45732, 42103, 34105, 32999, 29838, 29052, 23847, 316975]
# 11
# 11
# ['Requester #1', 'Requester #2', 'Requester #3', 'Requester #4', 'Requester #5', 'Requester #6', 'Requester #7', 'Requester #8', 'Requester #9', 'Requester #10', 'Rest of Requesters']
